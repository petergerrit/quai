# %%
import numpy as np

# %%
def is_mem(elem, array):
    is_member=False
    for item in array:
        if np.linalg.svd(elem-item).S.max() < 10**-4:
            is_member=True
            break
    return is_member
