# %%
from langchain.tools import tool
from langchain.agents import create_agent

from langchain_ollama import ChatOllama
# ollama pull llama3.1

# %%
# Here we define all the tools or "functions" that our agent will have access to 

@tool
def func1(x: float, y: float) -> float:
    """Multiply two numbers."""
    return x * y

def func2(x: float, y: float) -> float:
    """Multiply two numbers."""
    return x + y

tools = [func1, func2]

# %%
# This is the LLM model our Agent will use for the conversations and reasoning part
# We are using a simple ollama model but we can use GPT-SSO with Fermilab resources

model = ChatOllama(model="llama2", temperature=0.1) # temperature is how creative the model is (low is less creative)

# %%
# Here we build our agent and feed the model, the tools the description or prupose of the model, memory etc
# https://reference.langchain.com/python/langchain/agents/#langchain.agents.create_agent(checkpointer)


agent = create_agent(
    model=model,
    tools=tools,
    system_prompt="You are a helpful agent that reasons step-by-step and uses tools.", # shape how your agent approaches tasks
)

# %%
# Here is where we call the agent and tell it the user is asking...

response = agent.invoke({"messages":[{
                'role': 'user', 'content': '"10 people are coming to my party.  I want two cupcakes per person.  How many cupcakes should I buy?"'
                }]
                })
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Here is where we call the agent and tell it the user is asking...
# ----> 3 response = agent.invoke({"messages":[{
#       4                 'role': 'user', 'content': '"10 people are coming to my party.  I want two cupcakes per person.  How many cupcakes should I buy?"'
#       5                 }]
#       6                 })
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/pregel/main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/pregel/main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain/agents/factory.py:1131, in create_agent.<locals>.model_node(state, runtime)
#    1118 request = ModelRequest(
#    1119     model=model,
#    1120     tools=default_tools,
#    (...)
#    1126     runtime=runtime,
#    1127 )
#    1129 if wrap_model_call_handler is None:
#    1130     # No handlers - execute directly
# -> 1131     response = _execute_model_sync(request)
#    1132 else:
#    1133     # Call composed handler with base handler
#    1134     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain/agents/factory.py:1102, in create_agent.<locals>._execute_model_sync(request)
#    1099 if request.system_message:
#    1100     messages = [request.system_message, *messages]
# -> 1102 output = model_.invoke(messages)
#    1103 if name:
#    1104     output.name = name
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)
#    5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)
#     391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)
#    1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1030, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1023 def _generate(
#    1024     self,
#    1025     messages: list[BaseMessage],
#    (...)
#    1028     **kwargs: Any,
#    1029 ) -> ChatResult:
# -> 1030     final_chunk = self._chat_stream_with_aggregation(
#    1031         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1032     )
#    1033     generation_info = final_chunk.generation_info
#    1034     chat_generation = ChatGeneration(
#    1035         message=AIMessage(
#    1036             content=final_chunk.text,
#    (...)
#    1043         generation_info=generation_info,
#    1044     )
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:965, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     956 def _chat_stream_with_aggregation(
#     957     self,
#     958     messages: list[BaseMessage],
#    (...)
#     962     **kwargs: Any,
#     963 ) -> ChatGenerationChunk:
#     964     final_chunk = None
# --> 965     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     966         if final_chunk is None:
#     967             final_chunk = chunk
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1054, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1047 def _iterate_over_stream(
#    1048     self,
#    1049     messages: list[BaseMessage],
#    1050     stop: list[str] | None = None,
#    1051     **kwargs: Any,
#    1052 ) -> Iterator[ChatGenerationChunk]:
#    1053     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1054     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1055         if not isinstance(stream_resp, str):
#    1056             content = (
#    1057                 stream_resp["message"]["content"]
#    1058                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1059                 else ""
#    1060             )
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:952, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     950 if chat_params["stream"]:
#     951     if self._client:
# --> 952         yield from self._client.chat(**chat_params)
#     953 elif self._client:
#     954     yield self._client.chat(**chat_params)
#
# File ~/.venvs/MyEnv/lib/python3.12/site-packages/ollama/_client.py:179, in Client._request.<locals>.inner()
#     177 except httpx.HTTPStatusError as e:
#     178   e.response.read()
# --> 179   raise ResponseError(e.response.text, e.response.status_code) from None
#     181 for line in r.iter_lines():
#     182   part = json.loads(line)
#
# ResponseError: model 'llama2' not found (status code: 404)
# During task with name 'model' and id '44c20a6c-3200-4d98-8e72-28f81b8341f7'

# %%
print(response)
print(response['messages'][-1].content)
